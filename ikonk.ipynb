# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py

# %%
data_sets = (100, 5000, 11000)

vol_100 = np.fromfile('k100_1.bin')
l = int(np.round(np.power(vol_100.shape[0], 1./3)))
vol_100 = vol_100.reshape((l, l, l))
plt.figure(figsize=(20,10))
plt.subplot(131)
plt.imshow(np.log(vol_100[l//2,:,:]+0.001))
plt.subplot(132)
plt.imshow(np.log(vol_100[:,l//2,:]+0.001))
plt.subplot(133)
plt.imshow(np.log(vol_100[:,:,l//2]+0.001))

# %%
model = h5py.File('k100_model.h5', 'r')
vol_100m = np.asarray(model['rotated_model'])
plt.figure(figsize=(20,10))
plt.subplot(131)
plt.imshow(np.log(vol_100m[l//2,:,:]+0.001))
plt.subplot(132)
plt.imshow(np.log(vol_100m[:,l//2,:]+0.001))
plt.subplot(133)
plt.imshow(np.log(vol_100m[:,:,l//2]+0.001))
print np.asarray(model['rotation_angles'])
# Out:
# [0.3694464  0.26921619 0.35141749]

# %%
model = h5py.File('k5000_model.h5', 'r')
vol_5000m = np.asarray(model['rotated_model'])
plt.figure(figsize=(20,10))
plt.subplot(131)
plt.imshow(np.log(vol_5000m[l//2,:,:]+0.001))
plt.subplot(132)
plt.imshow(np.log(vol_5000m[:,l//2,:]+0.001))
plt.subplot(133)
plt.imshow(np.log(vol_5000m[:,:,l//2]+0.001))

# %%
vol_5000 = np.fromfile('k5000_1.bin')
l = int(np.round(np.power(vol_5000.shape[0], 1./3)))
vol_5000 = vol_5000.reshape((l, l, l))
plt.figure(figsize=(20,10))
plt.subplot(131)
plt.imshow(np.log(vol_5000[l//2,:,:]+0.001))
plt.subplot(132)
plt.imshow(np.log(vol_5000[:,l//2,:]+0.001))
plt.subplot(133)
plt.imshow(np.log(vol_5000[:,:,l//2]+0.001))
print np.asarray(model['rotation_angles'])
# Out:
# [0.3694464  0.26921619 0.35141749]

# %%
vol_11000 = np.fromfile('k11000_1.bin')
l = int(np.round(np.power(vol_11000.shape[0], 1./3)))
vol_11000 = vol_11000.reshape((l, l, l))
plt.figure(figsize=(20,10))
plt.subplot(131)
plt.imshow(np.log(vol_11000[l//2,:,:]+0.001))
plt.subplot(132)
plt.imshow(np.log(vol_11000[:,l//2,:]+0.001))
plt.subplot(133)
plt.imshow(np.log(vol_11000[:,:,l//2]+0.001))
print np.asarray(model['rotation_angles'])
# Out:
# [0.90703341 0.11198751 1.1795517 ]

# %%
model = h5py.File('k11000_model.h5', 'r')
vol_11000m = np.asarray(model['rotated_model'])
plt.figure(figsize=(20,10))
plt.subplot(131)
plt.imshow(np.log(vol_11000m[l//2,:,:]+0.001))
plt.subplot(132)
plt.imshow(np.log(vol_11000m[:,l//2,:]+0.001))
plt.subplot(133)
plt.imshow(np.log(vol_11000m[:,:,l//2]+0.001))
print np.asarray(model['rotation_angles'])
# Out:
# [0.81275853 0.39095762 0.69462773]
